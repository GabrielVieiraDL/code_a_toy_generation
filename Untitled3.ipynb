# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielVieiraDL/code_a_toy_generation/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_alunos = ["Lucas D1","Lucas S3","Luana", "Evelin"]
list_alturas = [1.83, 1.72, 1.64, 1.67]
list_idades = [21, 25, 31, 24]

print(list_alunos[-1])
print(list_alturas[-1])
print(list_idades[-1])

list_professores = ["Felipe", "Marcelo", "Luyz"]

print(f"os professores de 2025 são: {list_professores}")

print('Em 2026, temos um novo professor e a lista vai ficar: ')

novo_professor = input('Informe o nome do novo professor: ')

list_professores.append(novo_professor)

print(list_professores)

list_professores.pop(1)
print(list_professores)
# Out:
# Evelin
# 1.67
# 24
# os professores de 2025 são: ['Felipe', 'Marcelo', 'Luyz']
# Em 2026, temos um novo professor e a lista vai ficar:
# Informe o nome do novo professor: Ya
# ['Felipe', 'Marcelo', 'Luyz', 'Ya']
# ['Felipe', 'Luyz', 'Ya']

# %%
import random

list_dado = [1,2,3,4,5,6]

sortear = random.choice(list_dado)
print(sortear)
# Out:
# 3

# %%
import random

list_pets = ["Meg","Duda","Pandora","Joy","Garoa","Mini","Soneca","Honda","Lucky","Bingo"]

sortear = random.choice(list_pets)
print(sortear)

remover = list_pets



print(remover)
# Out:
# Joy
# None
