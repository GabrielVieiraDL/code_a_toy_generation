# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielVieiraDL/code_a_toy_generation/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = int(input('Informe um número: '))
numero2 = int(input('Informe outro número: '))

if numero1 > numero2:
  print('O número 1 é maior do que o número 2')
elif numero1 == numero2:
  print('Os valores são iguais')
else:
  print('O número 2 é maior que o número 1')
# Out:
# Informe um número: 5
# Informe outro número: 5
# Os valores são iguais

# %%
valor1 = int(input('Digite o primeiro valor: '))

valor2 = int(input('Digite o segundo valor: '))

soma = valor1 + valor2

if soma % 2 == 0:
  print('O valor é par')
else:
  print('O valor é ímpar')
# Out:
# Digite o primeiro valor: 5
# Digite o segundo valor: 5
# O valor é par
