# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielVieiraDL/generation/blob/main/dicionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict_venda = {
    "id_transacao":1001,
    "produto":"Smartphone",
    "categoria":"Eletrônico",
    "preco":2500.00,
    "quantidade":2,
    "ativo":True
}
# podemos acessar os valores
print(dict_venda['produto'])

# usar apenar print(dict['chave'] não é uma boa pratica)
print(dict_venda.get('desconto',"0%"))

# outros métodos de ver dados
print(dict_venda.keys())
print(dict_venda.values())
print(dict_venda.items())
# Out:
# Smartphone
# 0%
# dict_keys(['id_transacao', 'produto', 'categoria', 'preco', 'quantidade', 'ativo'])
# dict_values([1001, 'Smartphone', 'Eletrônico', 2500.0, 2, True])
# dict_items([('id_transacao', 1001), ('produto', 'Smartphone'), ('categoria', 'Eletrônico'), ('preco', 2500.0), ('quantidade', 2), ('ativo', True)])

# %%
# CRUD
# create
# read
# update
# delete

# vamos add uma nova chave - queremos a chave valor da compra
dict_venda['valor_compra'] = dict_venda['preco'] * dict_venda['quantidade']
print(dict_venda['valor_compra'])

# queremos alterar um valor existente do dicionario
dict_venda['preco'] = 2600
print(dict_venda)

# .update() - atualizar ou adicionar muitos campos de uma vez
novos_dados = {
    'cidade': "São Paulo",
    'canal_venda': "online",
    'plataforma': "Shopee",
    'produto': "Smartphone Motorola"
}
# Fazer
dict_venda.update(novos_dados)
print(dict_venda)

# Vamos remover / deletar uma informação
canal = dict_venda.pop('canal_venda')
print(dict_venda)
# Out:
# 5200
# {'id_transacao': 1001, 'produto': 'Smartphone Motorola', 'categoria': 'Eletrônico', 'preco': 2600, 'quantidade': 2, 'ativo': True, 'valor_compra': 5200, 'cidade': 'São Paulo', 'canal_venda': 'online', 'plataforma': 'Shopee'}
# {'id_transacao': 1001, 'produto': 'Smartphone Motorola', 'categoria': 'Eletrônico', 'preco': 2600, 'quantidade': 2, 'ativo': True, 'valor_compra': 5200, 'cidade': 'São Paulo', 'canal_venda': 'online', 'plataforma': 'Shopee'}
# {'id_transacao': 1001, 'produto': 'Smartphone Motorola', 'categoria': 'Eletrônico', 'preco': 2600, 'quantidade': 2, 'ativo': True, 'valor_compra': 5200, 'cidade': 'São Paulo', 'plataforma': 'Shopee'}

# %%
# vamos ver esses dados de maneira mais apresentavel (FOR)

for chave, valor in dict_venda.items():
  print(f'{chave.capitalize()} : {valor}')
# Out:
# Id_transacao : 1001
# Produto : Smartphone Motorola
# Categoria : Eletrônico
# Preco : 2600
# Quantidade : 2
# Ativo : True
# Valor_compra : 5200
# Cidade : São Paulo
# Plataforma : Shopee

# %%
# Dicionários aninhados
dict_banco_clientes = {
    'clientes1' : {
        'nome' : "Luiz",
        'idade' : 32,
        'compras' : {'total_gasto' : 12000}
    },
    'clientes2' : {
        'nome' : "Felipe",
        'idade' : 35,
        'compras' : {'total_gasto' : 8000}
    }
}

# desafio simples
# acessar os dados do cliente 1
print(dict_banco_clientes['clientes1']['nome'])

# acessar o total gasto
print(dict_banco_clientes['clientes1']['compras']['total_gasto'])

# se temos um dicionario aninhado e queremos exibir valores iguais de dentro
for chave, valor in dict_banco_clientes.items():
  nome = valor['nome']
  print(nome)

for i in dict_banco_clientes.values() :
  print(i['nome'])
# Out:
# Luiz
# 12000
# Luiz
# Felipe
# Luiz
# Felipe
